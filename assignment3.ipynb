# %%
# program to check right angle triangle
def check_triangle(k,l,m):
    if k*k==l*l+m*m:
        print(" It is a right angle triangle")
    elif l*l==k*k+m*m:
        print("It is a right angle triangle")
    elif m*m==k*k+l*l:
        print("It is a right angle triangle")
    else:
        print("It is not a  right angled triangle")
k=int(input("Enter the first side:"))
l=int(input("Enter the second side:"))
m=int(input("Enter the third side:"))

check_triangle(k,l,m)
# Out:
# Enter the first side: 5
# Enter the second side:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 12
#      10         print("It is not a  right angled triangle")
#      11 k=int(input("Enter the first side:"))
# ---> 12 l=int(input("Enter the second side:"))
#      13 m=int(input("Enter the third side:"))
#      15 check_triangle(k,l,m)
#
# ValueError: invalid literal for int() with base 10: ''
