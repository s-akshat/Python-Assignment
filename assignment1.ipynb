# %%
# list operations
list1 = ["Ram","Shyam","CHAMAN"]
print(list1)
# Out:
# ['Ram', 'Shyam', 'CHAMAN']

# %%
list1.append("diya")
print(list1)
# Out:
# ['Ram', 'Shyam', 'CHAMAN', 'diya']

# %%
list1.insert(3,"bhavya")
print(list1)
# Out:
# ['Ram', 'Shyam', 'CHAMAN', 'bhavya', 'diya']

# %%
list1.remove("CHAMAN")
print(list1)
# Out:
# ['Ram', 'Shyam', 'bhavya', 'diya']

# %%
list1.pop(2)
print(list1)
# Out:
# ['Ram', 'Shyam', 'diya']

# %%
list1.extend(["akash","aryaman"])
print(list1)
# Out:
# ['aarav', 'chetan', 'divya', 'akash', 'aryaman']

# %%
list1.sort()
print(list1)
# Out:
# ['aarav', 'chetan', 'divya']

# %%
# tuple operations
tuple1 =  ("Ram","Shyam","CHAMAN")
print(tuple1)
# Out:
# ('Ram', 'Shyam', 'CHAMAN')

# %%
# length of the tuple
print(len(tuple1))
# Out:
# 3

# %%
# adding element
tuple1 = ("Ram","Shyam","CHAMAN")
x = ("divya",)
tuple1 += x
print("add tuple function:",tuple1)
# Out:
# add tuple function: ('Ram', 'Shyam', 'CHAMAN', 'divya')

# %%
# multiplying the tuple 
tuple1 = ("Ram","Shyam","CHAMAN")
tuple2 = tuple1*3
print(tuple2)
# Out:
# ('Ram', 'Shyam', 'CHAMAN', 'Ram', 'Shyam', 'CHAMAN', 'Ram', 'Shyam', 'CHAMAN')

# %%
t = ("aarav","chetan","bhavana")
print(t)
a = list(t)
print(a)
a.append("divya")
t=tuple(a)
print(a)
# Out:
# ('aarav', 'chetan', 'bhavana')
# ['aarav', 'chetan', 'bhavana']
# ['aarav', 'chetan', 'bhavana', 'divya']

# %%
# dictionary operations
students = {101:"Ram",102:"Shyam",103:"CHAMAN"}
print(students)
# Out:
# {101: 'Ram', 102: 'Shyam', 103: 'CHAMAN'}

# %%
# accessing the value
print(students[102])
# Out:
# Shyam

# %%
# adding the element 
students[104]="divya"
students
# Out:
# {101: 'Ram', 102: 'Shyam', 103: 'CHAMAN', 104: 'divya'}

# %%
print(students.keys())
# Out:
# dict_keys([101, 102, 103, 104])

# %%
print(students.values())
# Out:
# dict_values(['Ram', 'Shyam', 'CHAMAN', 'divya'])

# %%
print(students.items())
# Out:
# dict_items([(101, 'Ram'), (102, 'Shyam'), (103, 'CHAMAN'), (104, 'divya')])

# %%
students.pop(101)
print(students)
# Out:
# {102: 'Shyam', 103: 'CHAMAN', 104: 'divya'}
